# %%
#importing libraries

import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading the data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df_altered = df.copy()

# %%
id(df_altered) == id(df)
# Out:
# False

# %%
df_altered.sample(10,replace=True)
# Out:
#               job_title_short  \
# 680351  Senior Data Scientist
# 110348           Data Analyst
# 569662          Data Engineer
# 345532  Senior Data Scientist
# 710674           Data Analyst
# 177650           Data Analyst
# 105206       Business Analyst
# 382043         Data Scientist
# 470427         Data Scientist
# 168190           Data Analyst
#
#                                                 job_title  \
# 680351  Senior Data Specialist/Data Scientist (2 Years...
# 110348  Alternance-Marketing Data Analyst H/F - Immedi...
# 569662                             Data Platform Engineer
# 345532            Sr Principal Data Scientist/ML Engineer
# 710674  Data Analyst – Reporting, Data Management Serv...
# 177650                                       Data Analyst
# 105206                                        QA Engineer
# 382043                                 Sr. Data Scientist
# 470427                      Data Science Program Director
# 168190                       PROJECT MANAGER/DATA ANALYST
#
#                                           job_location                job_via  \
# 680351                        Mpumalanga, South Africa             via Indeed
# 110348                                   Paris, France           via GrabJobs
# 569662                        Gurugram, Haryana, India           via LinkedIn
# 345532                                      Denver, CO        via Recruit.net
# 710674                                  Kraków, Poland  via Praca Trabajo.org
# 177650                                   Charlotte, NC           via LinkedIn
# 105206                                 Porto, Portugal           via Sercanto
# 382043                                      Boston, MA        via Trabajo.org
# 470427                                   United States        via Trabajo.org
# 168190  Rome, Metropolitan City of Rome Capital, Italy           via LinkedIn
#
#        job_schedule_type  job_work_from_home          search_location  \
# 680351        Contractor               False             South Africa
# 110348         Full-time               False                   France
# 569662         Full-time               False                    India
# 345532         Full-time               False                    Sudan
# 710674         Full-time               False                   Poland
# 177650        Contractor               False                  Georgia
# 105206         Full-time               False                 Portugal
# 382043         Full-time               False  New York, United States
# 470427         Full-time               False                    Sudan
# 168190         Full-time               False                    Italy
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 680351 2023-03-28 10:55:16                  False                 False
# 110348 2023-07-06 00:29:10                  False                 False
# 569662 2023-07-22 09:10:25                  False                 False
# 345532 2023-04-01 23:55:04                  False                  True
# 710674 2023-09-01 02:53:51                  False                 False
# 177650 2023-03-01 16:12:30                   True                 False
# 105206 2023-05-02 00:23:29                  False                 False
# 382043 2023-07-26 18:02:59                  False                 False
# 470427 2023-09-04 14:31:59                  False                 False
# 168190 2023-12-19 15:41:33                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 680351   South Africa        None              NaN              NaN
# 110348         France        None              NaN              NaN
# 569662          India        None              NaN              NaN
# 345532          Sudan        None              NaN              NaN
# 710674         Poland        None              NaN              NaN
# 177650  United States        None              NaN              NaN
# 105206       Portugal        None              NaN              NaN
# 382043  United States        None              NaN              NaN
# 470427          Sudan        None              NaN              NaN
# 168190          Italy        None              NaN              NaN
#
#                                         company_name  \
# 680351                                  AJ Personnel
# 110348                                        Lyreco
# 569662                                 NatWest Group
# 345532                                       myGwork
# 710674  Lufthansa Group Business Services Sp. z o.o.
# 177650                                  Apex Systems
# 105206                                   Global Blue
# 382043                                Shoptrue, Inc.
# 470427            University of California San Diego
# 168190                       Allianz Trade in Italia
#
#                                                job_skills  \
# 680351                         ['sas', 'sas', 'r', 'sql']
# 110348                                               None
# 569662  ['mongodb', 'mongodb', 'no-sql', 'python', 'ja...
# 345532  ['python', 'go', 'oracle', 'scikit-learn', 'te...
# 710674          ['sharepoint', 'excel', 'sap', 'tableau']
# 177650  ['sql', 'sas', 'sas', 'python', 'r', 'matlab',...
# 105206                              ['sql', 'sql server']
# 382043               ['sql', 'python', 'spark', 'pandas']
# 470427                                               None
# 168190                                               None
#
#                                           job_type_skills
# 680351  {'analyst_tools': ['sas'], 'programming': ['sa...
# 110348                                               None
# 569662  {'cloud': ['oracle', 'aws', 'gcp', 'azure', 's...
# 345532  {'cloud': ['oracle'], 'libraries': ['scikit-le...
# 710674  {'analyst_tools': ['sharepoint', 'excel', 'sap...
# 177650  {'analyst_tools': ['sas', 'tableau'], 'librari...
# 105206  {'databases': ['sql server'], 'programming': [...
# 382043  {'libraries': ['spark', 'pandas'], 'programmin...
# 470427                                               None
# 168190                                               None
