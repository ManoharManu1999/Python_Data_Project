# %%
#importing libraries

import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#loading the data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
india_df = df[df["job_country"] == "India"].copy()

# %%
india_df.head()
# Out:
#          job_title_short                                    job_title  \
# 16         Data Engineer                            Big Data Engineer
# 19        Data Scientist                               Data Scientist
# 29        Data Scientist                               Data Scientist
# 38          Data Analyst        Data Quality and Governance Analyst 1
# 42  Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                   job_location  \
# 16    Pune, Maharashtra, India
# 19    Pune, Maharashtra, India
# 29    Pune, Maharashtra, India
# 38                       India
# 42  Chennai, Tamil Nadu, India
#
#                                               job_via job_schedule_type  \
# 16                                       via LinkedIn         Full-time
# 19                                         via Indeed         Full-time
# 29                                         via Exusia         Full-time
# ...

# %%
india_df["job_posted_month"] = india_df["job_posted_date"].dt.to_period("M")

# %%
india_df.head(3)
# Out:
#    job_title_short          job_title              job_location       job_via  \
# 16   Data Engineer  Big Data Engineer  Pune, Maharashtra, India  via LinkedIn
# 19  Data Scientist     Data Scientist  Pune, Maharashtra, India    via Indeed
# 29  Data Scientist     Data Scientist  Pune, Maharashtra, India    via Exusia
#
#    job_schedule_type  job_work_from_home search_location     job_posted_date  \
# 16         Full-time               False           India 2023-06-15 13:28:03
# 19         Full-time               False           India 2023-04-26 13:20:12
# 29         Full-time               False           India 2023-03-26 13:16:20
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 16                  False                 False       India        None
# 19                  False                 False       India        None
# 29                  False                 False       India        None
#
# ...

# %%
df_india_pivot = india_df.pivot_table(index="job_posted_month", columns="job_title_short", aggfunc="size")

# %%
df_india_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# 2023-01                        175              31           628
# 2023-02                        143              35           433
# 2023-03                        116              37           422
# 2023-04                        170              32           418
# 2023-05                        103              14           278
# 2023-06                        146              26           367
# 2023-07                        142              25           457
# 2023-08                        189              25           618
# 2023-09                        155              34           630
# 2023-10                        170              36           500
# 2023-11                        192              29           722
# 2023-12                        186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_3 = india_df["job_title_short"].value_counts().head(3).index.to_list()
top_3
# Out:
# ['Data Engineer', 'Data Scientist', 'Data Analyst']

# %%
df_india_pivot[top_3].plot(kind="line")
# Out:
# <Axes: xlabel='job_posted_month'>
